# %% [markdown]
# # San Francisco Homeless Crisis

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Data](#data)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)
# * [Sources](#Source)

# %% [markdown]
# ## Library to import

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
import matplotlib.pyplot as plt # plotting library
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
# backend for rendering plots within the browser
# %matplotlib inline 
from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.10
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.10
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# Ever-evolving technology have continued to capture our surprise in new creative ideas and services. Software companies such as Google, Facebook, Uber, Twitter, and Instagram spurred from the San Francisco Bay Area, Silicon Valley and made its way to the world. Today these billion-dollar companies have brought a great number of people from all over the world to Northern California. Software developers and engineers have gathered to create and innovate in the Silicon Valley. On the flip side, there has been a clearly visible income gap amongst the people living in San Francisco.
# 	The income gap that has been flooded throughout the San Francisco Bay Area has created a ripple amongst families and individual that led some to move out of the city and some to live on the street. The housing price has inflated more than the average individual can afford.  “The average apartment rent over the prior 6 months in San Francisco has increased by $256 (7%) One bedroom units have increased by $306 (9.3%) and two-bedroom apartments have increased by $230 (5.2%).” (Jungle) People have begun being kicked out of their homes and without any warning, rents have skyrocketed. The housing has increased however many average workers in San Francisco’s income has not been raised.

# %%
data_csv = "housingstatistics2011-2019.csv"
housing_df = pd.read_csv(data_csv, usecols=['All Beds','1 Beds','2 Beds'])
month = pd.date_range('2011-01','2019-04', freq='MS').strftime("%Y-%d").tolist()
all_beds = housing_df['All Beds'].tolist()
one_beds = housing_df['1 Beds'].tolist()
two_beds = housing_df['2 Beds'].tolist()
df = pd.DataFrame({'All Beds':all_beds, '1 Beds':one_beds, '2 Beds':two_beds}, index=month)
ax = df.plot()

# %% [markdown]
# ### San Francisco Rent Trends

# %% [markdown]
# The situation for housing has become worse by the City of San Francisco taking actions that accentuate the rise in housing price in various situation. The city of San Francisco has continued to put a restriction on building permits on affordable housings, emphasizing environmental issue and minor issues such as “casting of the shadow on private property.” Many of the building in San Francisco needs to be remodeled since it’s more than a century old however many owners cannot get a permit. The number of homeless has exploded in the past several years.
# 	Due to poor living condition and lack of housing in San Francisco, a large number of families and individuals were led to live on the street. With very less oversight on the homeless from the City of San Francisco, homeless that has been living on the street has continued to persist. “In 2019, San Francisco reported 8,011 homeless people met the federal definition of homeless, an increase of 17 percent from 2017. When looking at San Francisco's expanded definition, the city's 2019 total homeless population is 9,784, the highest in the Bay Area.” (Eby)

# %% [markdown]
# ### San Francisco Homeless Census

# %%
year = [2007,2009,2011,2013,2015,2017,2019]
federal_poverty = [5703,5823,5669,7350,7539,7499,9784]
state_poverty = [5703,5823,5669,7008,6775,6858,8011]
df = pd.DataFrame({'Federal Poverty':federal_poverty, 'State Poverty':state_poverty}, index = year)
ax = df.plot.bar(rot=0)

# %% [markdown]
# Just the Federal count in homeless has doubled from ten years ago. There are almost ten thousand homeless people on the street in San Francisco, which has a surface area of only 46.87 mi^2.

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# From the numbers, we can expect the homeless to continue to grow. In order to help homeless’ to get back on their feet, we would first consider helping generate a stable income. Income majorly comes from occupancy and the high minimum wage in the city already serves the perfect condition. Although in order to even start occupancy, homeless’ need proper housing. Homeless carry their whole belongings around and cannot properly treat their hygiene without a form of housing. Homeless shelters are often overcrowded and weekly street cleaning forces them to continuously move one place to the other. It is certain that housing is the most critical problem that homeless’ have today.
# There are several limitations that we would need to consider in order to solve the homelessness in San Francisco.
# 1.	High housing cost to house the homeless individual and families.
# 2.	Restriction on building new affordable housing in San Francisco
# 3.	Difficulties renovating the current building for housing
# 4.	Overcrowded homeless shelters
#
# Considering the restraints above the only solution to homelessness is to rely on current infrastructure in order to provide housing to homeless’. Although current public infrastructure in San Francisco does not offer a great solution to house homeless’ on the street. It is not a large city and because of the building restriction, it is not made to house a large number of people at the same time. We would need to rely on private properties that are vacant most of the time, especially at night.
# In essence, the private property that is vacant at night and located all around the city are the 160 churches in San Francisco. If every church housed 20 homeless’, in just one day, half of all homeless in San Francisco will be cut in half. The effect would not only eliminate the homeless crisis but would open up homeless shelters for people in need. People would then find occupancy and the increasing homelessness would decrease in time. Churches would be rewarded through additional tax exemption and would be able to bring more people to their service. It would be a win-win deal for all people in San Francisco.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# In order to bring upon such mandate, there would be a need for a plan and a proof of concept to show that the proposition is valid and effective. In order to maximize the efficiency of housing, we cannot just allocate a static number of people in every church, however, there is no data set for the specific number each church can hold. So we would need to maximize the efficiency in housing homelessness in terms of proximity of each church. The closer the churches would be able to expand the housing cap, so if there is occupancy in another church nearby we would quickly be able to allocate people between each church.
# The proof of concept that would be proposed would first target the churches that are 800m within a radius of City Hall. Through the FourSquare database, we would be filtering the churches around City Hall that are 800m in radius and measuring the proximity of each church to each other and rank in terms of distance of proximity. Then we would be able to accurately measure how effective this proposition can be, with just an 800m radius.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# The proof of concept that would be proposed would first target the churches that are 800m within a radius of City Hall. Through the FourSquare database, we would be filtering the churches around City Hall that are 800m in radius and measuring the proximity of each church to each other. We will then rank and group in terms of distance of proximity. Then we would be able to accurately measure how effective this proposition can be, with just an 800m radius.

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'PBS53DUGKCOR2GTLDHHJN4QUCXSXWJJIAYPQWYFN04M0JRWB' # your Foursquare ID
CLIENT_SECRET = 'MGLT5MSRXGFPJ4I0RNT1BBZEIPQDYZGIHAGM2D1AZ2XQDASV' # your Foursquare Secret
VERSION = '20180604'
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: PBS53DUGKCOR2GTLDHHJN4QUCXSXWJJIAYPQWYFN04M0JRWB
# CLIENT_SECRET:MGLT5MSRXGFPJ4I0RNT1BBZEIPQDYZGIHAGM2D1AZ2XQDASV

# %% [markdown]
# #### San Francisco City Hall's address to its latitude and longitude coordinates.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = '1 Dr Carlton B Goodlett Pl, San Francisco, CA 94102'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print("latitude  {} \nlongitude {}".format(latitude, longitude))
# Out:
# latitude  37.7792929
# longitude -122.41926032381

# %% [markdown]
# #### Query for all Churches in San Francisco.

# %%
categoryId = '4bf58dd8d48988d132941735' # Spiritual Center Category
radius = 800
LIMIT = 1000 
print(' .... OK!')
# Out:
#  .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&LIMIT{}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, categoryId, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=PBS53DUGKCOR2GTLDHHJN4QUCXSXWJJIAYPQWYFN04M0JRWB&client_secret=MGLT5MSRXGFPJ4I0RNT1BBZEIPQDYZGIHAGM2D1AZ2XQDASV&ll=37.7792929,-122.41926032381&v=20180604&categoryId=4bf58dd8d48988d132941735&radius=800&LIMIT1000'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d414a4a9241f80025a7a49c'},
#  'response': {'venues': [{'id': '4b1324a0f964a520ab9423e3',
#     'name': 'Church of the Advent of Christ the King',
#     'location': {'address': '261 Fell St',
#      'crossStreet': 'Franklin/Gough',
#      'lat': 37.77586749910566,
#      'lng': -122.42176210277322,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77586749910566,
#        'lng': -122.42176210277322}],
#      'distance': 440,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['261 Fell St (Franklin/Gough)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4f25a3eae4b0c41c53d97e0f',
#     'name': 'Church Of The Nativity Of Our Lord',
#     'location': {'address': '240 Fell St',
#      'crossStreet': 'Franklin',
#      'lat': 37.77601662781605,
#      'lng': -122.42199178963958,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77601662781605,
#        'lng': -122.42199178963958}],
#      'distance': 436,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['240 Fell St (Franklin)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4db46b4f81543d71da452b08',
#     'name': 'Bethel A.M.E. Church',
#     'location': {'address': '916 Laguna St',
#      'crossStreet': '415-921-4935',
#      'lat': 37.780607093771145,
#      'lng': -122.42620241614902,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.780607093771145,
#        'lng': -122.42620241614902}],
#      'distance': 628,
#      'postalCode': '94115',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['916 Laguna St (415-921-4935)',
#       'San Francisco, CA 94115',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4db1e79e0cb6442b2ed407db',
#     'name': "St. Joseph's Roman Catholic Church",
#     'location': {'address': '1401 Howard St',
#      'lat': 37.773783,
#      'lng': -122.41440199,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.773783,
#        'lng': -122.41440199}],
#      'distance': 747,
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1401 Howard St',
#       'San Francisco, CA',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '590618d43d47912d4bcbe52e',
#     'name': 'Hillsong SF',
#     'location': {'address': '1300 Van Ness Ave',
#      'crossStreet': 'Post and Geary',
#      'lat': 37.78773094839714,
#      'lng': -122.42142860381412,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78773094839714,
#        'lng': -122.42142860381412}],
#      'distance': 958,
#      'postalCode': '94109',
#      'cc': 'US',
#      'neighborhood': 'Lower Nob Hill',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1300 Van Ness Ave (Post and Geary)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '447425541'},
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4bd9d33d2e6f0f47b0270c08',
#     'name': 'St Boniface Roman Catholic Church',
#     'location': {'address': '133 Golden Gate Ave',
#      'crossStreet': 'Jones St',
#      'lat': 37.78168454736256,
#      'lng': -122.41315795995622,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78168454736256,
#        'lng': -122.41315795995622}],
#      'distance': 599,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['133 Golden Gate Ave (Jones St)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4a5901fff964a52072b81fe3',
#     'name': 'Cathedral of Saint Mary of the Assumption',
#     'location': {'address': '1111 Gough St',
#      'crossStreet': 'btwn Geary Blvd & Ellis St',
#      'lat': 37.78472011778899,
#      'lng': -122.42508879670633,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78472011778899,
#        'lng': -122.42508879670633}],
#      'distance': 792,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1111 Gough St (btwn Geary Blvd & Ellis St)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4e63a775e4cdf1e2bfd08494',
#     'name': 'Hamilton Square Baptist Church',
#     'location': {'lat': 37.78568764726271,
#      'lng': -122.42297067496384,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78568764726271,
#        'lng': -122.42297067496384}],
#      'distance': 783,
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['San Francisco, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4f25b3abe4b0b2f990bffcf6',
#     'name': 'Neighborhood Baptist Church',
#     'location': {'address': '608 Hayes St, San Francisco, CA',
#      'crossStreet': 'Laguna',
#      'lat': 37.776578397700526,
#      'lng': -122.4266583680531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.776578397700526,
#        'lng': -122.4266583680531}],
#      'distance': 717,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['608 Hayes St, San Francisco, CA (Laguna)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4f3ab16ce4b059425ae6c621',
#     'name': 'SF City Impact',
#     'location': {'address': '230 Jones St',
#      'crossStreet': 'Turk',
#      'lat': 37.78349501668827,
#      'lng': -122.41222043720393,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78349501668827,
#        'lng': -122.41222043720393}],
#      'distance': 776,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['230 Jones St (Turk)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4aae74b5f964a520266220e3',
#     'name': "St Mark's Lutheran Church",
#     'location': {'address': '1111 Ofarrell St',
#      'crossStreet': 'btw Franklin & Gough',
#      'lat': 37.784304161326595,
#      'lng': -122.42365175129844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.784304161326595,
#        'lng': -122.42365175129844}],
#      'distance': 678,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1111 Ofarrell St (btw Franklin & Gough)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4e1fcb971fc7c0ef9856bfdb',
#     'name': 'Templo Calvario',
#     'location': {'address': '1419 Howard St',
#      'crossStreet': 'between 10th & 11th',
#      'lat': 37.773038442147985,
#      'lng': -122.41503238677979,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.773038442147985,
#        'lng': -122.41503238677979}],
#      'distance': 789,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1419 Howard St (between 10th & 11th)',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '50ce82c8e4b0b0b98afb8f98',
#     'name': 'Saint Paulus Luthern Church',
#     'location': {'address': '950 McAllister St',
#      'lat': 37.77915867148549,
#      'lng': -122.4283239654184,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77915867148549,
#        'lng': -122.4283239654184}],
#      'distance': 797,
#      'postalCode': '94115',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['950 McAllister St',
#       'San Francisco, CA 94115',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4c4c7c0646240f47af17ddf4',
#     'name': 'San Francisco Lighthouse Church',
#     'location': {'address': '1337 Sutter St',
#      'crossStreet': 'Van Ness Ave',
#      'lat': 37.787270154855335,
#      'lng': -122.4223736386057,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.787270154855335,
#        'lng': -122.4223736386057}],
#      'distance': 929,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1337 Sutter St (Van Ness Ave)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4a882c71f964a520530520e3',
#     'name': 'Glide Memorial Church',
#     'location': {'address': '330 Ellis St',
#      'crossStreet': 'Ofarrell',
#      'lat': 37.785142557901864,
#      'lng': -122.41133179520415,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.785142557901864,
#        'lng': -122.41133179520415}],
#      'distance': 954,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['330 Ellis St (Ofarrell)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4be2e78121d5a59352951711',
#     'name': 'First Baptist Church of San Francisco',
#     'location': {'address': '22 Waller St',
#      'crossStreet': 'at Octavia St.',
#      'lat': 37.77234190177588,
#      'lng': -122.4239341477818,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77234190177588,
#        'lng': -122.4239341477818}],
#      'distance': 876,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['22 Waller St (at Octavia St.)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4e5a64ef1495a891128b32ff',
#     'name': 'St Paulus Lutheran Church',
#     'location': {'address': '1541 Polk St',
#      'crossStreet': 'Sacramento',
#      'lat': 37.779150540488224,
#      'lng': -122.42835727177484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.779150540488224,
#        'lng': -122.42835727177484}],
#      'distance': 800,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1541 Polk St (Sacramento)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '44281351'},
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4bec64c4fd60a59373ef3af1',
#     'name': 'San Francisco City Impact Headquarters',
#     'location': {'address': '136 Taylor St',
#      'crossStreet': 'Turk St.',
#      'lat': 37.783026,
#      'lng': -122.410774,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.783026,
#        'lng': -122.410774}],
#      'distance': 854,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['136 Taylor St (Turk St.)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '49ee3587f964a52039681fe3',
#     'name': 'Unitarian Universalist Church',
#     'location': {'address': '1187 Franklin St',
#      'crossStreet': 'Geary',
#      'lat': 37.784910184864025,
#      'lng': -122.4232013790953,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.784910184864025,
#        'lng': -122.4232013790953}],
#      'distance': 715,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1187 Franklin St (Geary)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '51edc92b498e75cde831fe24',
#     'name': 'Church Of The Assumption Of Mary',
#     'location': {'address': '1111 Gough St. @ Geary Blvd.',
#      'lat': 37.784218,
#      'lng': -122.425251,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.784218,
#        'lng': -122.425251}],
#      'distance': 760,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Quentin',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1111 Gough St. @ Geary Blvd.',
#       'San Quentin, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4c683d7c832bc9285f9eb3a8',
#     'name': 'Journey SF',
#     'location': {'address': '1290 Sutter St',
#      'lat': 37.78796485412996,
#      'lng': -122.42170191454402,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78796485412996,
#        'lng': -122.42170191454402}],
#      'distance': 988,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1290 Sutter St',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4c4cec4674e81b8deaa9fa06',
#     'name': 'Freedom in Christ Evangelical Church',
#     'location': {'address': '1031 Franklin St',
#      'crossStreet': "at O'Farrell St.",
#      'lat': 37.784343,
#      'lng': -122.423143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.784343,
#        'lng': -122.423143}],
#      'distance': 657,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ["1031 Franklin St (at O'Farrell St.)",
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '49003178'},
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4ee01fea0e61e7dd0d1fa4c0',
#     'name': 'TSA - Kroc Center Corps Youth Night',
#     'location': {'lat': 37.782953,
#      'lng': -122.413077,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.782953,
#        'lng': -122.413077}],
#      'distance': 679,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['San Francisco, CA 94102', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4e2baf15aeb745b1fac6c5f7',
#     'name': 'TSA - Kroc Center Sunday Worship Service',
#     'location': {'address': '240 Turk St',
#      'crossStreet': 'Jones',
#      'lat': 37.782969,
#      'lng': -122.413078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.782969,
#        'lng': -122.413078}],
#      'distance': 680,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['240 Turk St (Jones)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4e87443b5c5c38d515050d6f',
#     'name': 'SFGMC Rehearsal/FUUC',
#     'location': {'lat': 37.78529995482023,
#      'lng': -122.42220194658034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78529995482023,
#        'lng': -122.42220194658034}],
#      'distance': 717,
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['San Francisco, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4d8a85af76e1236a4c8f1c43',
#     'name': 'San Francisco Worship Center',
#     'location': {'address': '230 Jones St',
#      'lat': 37.78402507,
#      'lng': -122.41280408,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78402507,
#        'lng': -122.41280408}],
#      'distance': 774,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['230 Jones St',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4e10a0aac65b4a49f305bbac',
#     'name': 'TSA - Kroc Center Corps Sunday School',
#     'location': {'lat': 37.782927,
#      'lng': -122.413165,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.782927,
#        'lng': -122.413165}],
#      'distance': 671,
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['San Francisco, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False},
#    {'id': '4d1541f9816af04d0f5042c2',
#     'name': "Saint Paul's Lutheran Church",
#     'location': {'address': '950 McAllister St',
#      'lat': 37.77904,
#      'lng': -122.428512,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77904,
#        'lng': -122.428512}],
#      'distance': 814,
#      'cc': 'US',
#      'state': 'California',
#      'country': 'United States',
#      'formattedAddress': ['950 McAllister St', 'California', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564559946',
#     'hasPerk': False}],
#   'confident': False}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                     name  \
# 0  4b1324a0f964a520ab9423e3  Church of the Advent of Christ the King
# 1  4f25a3eae4b0c41c53d97e0f       Church Of The Nativity Of Our Lord
# 2  4db46b4f81543d71da452b08                     Bethel A.M.E. Church
# 3  4db1e79e0cb6442b2ed407db       St. Joseph's Roman Catholic Church
# 4  590618d43d47912d4bcbe52e                              Hillsong SF
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...  v-1564559946    False
# 1  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...  v-1564559946    False
# 2  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...  v-1564559946    False
# 3  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...  v-1564559946    False
# 4  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...  v-1564559946    False
#
#     location.address location.crossStreet  location.lat  location.lng  \
# 0        261 Fell St       Franklin/Gough     37.775867   -122.421762
# 1        240 Fell St             Franklin     37.776017   -122.421992
# 2      916 Laguna St         415-921-4935     37.780607   -122.426202
# 3     1401 Howard St                  NaN     37.773783   -122.414402
# 4  1300 Van Ness Ave       Post and Geary     37.787731   -122.421429
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 37.77586749910566...                440
# 1  [{'label': 'display', 'lat': 37.77601662781605...                436
# 2  [{'label': 'display', 'lat': 37.78060709377114...                628
# 3  [{'label': 'display', 'lat': 37.773783, 'lng':...                747
# 4  [{'label': 'display', 'lat': 37.78773094839714...                958
#
#   location.postalCode location.cc  location.city location.state  \
# 0               94102          US  San Francisco             CA
# 1               94102          US  San Francisco             CA
# 2               94115          US  San Francisco             CA
# 3                 NaN          US  San Francisco             CA
# 4               94109          US  San Francisco             CA
#
#   location.country                          location.formattedAddress  \
# 0    United States  [261 Fell St (Franklin/Gough), San Francisco, ...
# 1    United States  [240 Fell St (Franklin), San Francisco, CA 941...
# 2    United States  [916 Laguna St (415-921-4935), San Francisco, ...
# 3    United States  [1401 Howard St, San Francisco, CA, United Sta...
# 4    United States  [1300 Van Ness Ave (Post and Geary), San Franc...
#
#   location.neighborhood venuePage.id
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4        Lower Nob Hill    447425541

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered
# Out:
#                                          name categories  \
# 0     Church of the Advent of Christ the King     Church
# 1          Church Of The Nativity Of Our Lord     Church
# 2                        Bethel A.M.E. Church     Church
# 3          St. Joseph's Roman Catholic Church     Church
# 4                                 Hillsong SF     Church
# 5           St Boniface Roman Catholic Church     Church
# 6   Cathedral of Saint Mary of the Assumption     Church
# 7              Hamilton Square Baptist Church     Church
# 8                 Neighborhood Baptist Church     Church
# 9                              SF City Impact     Church
# 10                  St Mark's Lutheran Church     Church
# 11                            Templo Calvario     Church
# 12                Saint Paulus Luthern Church     Church
# 13            San Francisco Lighthouse Church     Church
# 14                      Glide Memorial Church     Church
# 15      First Baptist Church of San Francisco     Church
# 16                  St Paulus Lutheran Church     Church
# 17     San Francisco City Impact Headquarters     Church
# 18              Unitarian Universalist Church     Church
# 19           Church Of The Assumption Of Mary     Church
# 20                                 Journey SF     Church
# 21       Freedom in Christ Evangelical Church     Church
# 22        TSA - Kroc Center Corps Youth Night     Church
# 23   TSA - Kroc Center Sunday Worship Service     Church
# 24                       SFGMC Rehearsal/FUUC     Church
# 25               San Francisco Worship Center     Church
# 26      TSA - Kroc Center Corps Sunday School     Church
# 27               Saint Paul's Lutheran Church     Church
#
#                             address                 crossStreet        lat  \
# 0                       261 Fell St              Franklin/Gough  37.775867
# 1                       240 Fell St                    Franklin  37.776017
# 2                     916 Laguna St                415-921-4935  37.780607
# 3                    1401 Howard St                         NaN  37.773783
# 4                 1300 Van Ness Ave              Post and Geary  37.787731
# 5               133 Golden Gate Ave                    Jones St  37.781685
# 6                     1111 Gough St  btwn Geary Blvd & Ellis St  37.784720
# 7                               NaN                         NaN  37.785688
# 8   608 Hayes St, San Francisco, CA                      Laguna  37.776578
# 9                      230 Jones St                        Turk  37.783495
# 10                 1111 Ofarrell St        btw Franklin & Gough  37.784304
# 11                   1419 Howard St         between 10th & 11th  37.773038
# 12                950 McAllister St                         NaN  37.779159
# 13                   1337 Sutter St                Van Ness Ave  37.787270
# 14                     330 Ellis St                    Ofarrell  37.785143
# 15                     22 Waller St              at Octavia St.  37.772342
# 16                     1541 Polk St                  Sacramento  37.779151
# 17                    136 Taylor St                    Turk St.  37.783026
# 18                 1187 Franklin St                       Geary  37.784910
# 19     1111 Gough St. @ Geary Blvd.                         NaN  37.784218
# 20                   1290 Sutter St                         NaN  37.787965
# 21                 1031 Franklin St            at O'Farrell St.  37.784343
# 22                              NaN                         NaN  37.782953
# 23                      240 Turk St                       Jones  37.782969
# 24                              NaN                         NaN  37.785300
# 25                     230 Jones St                         NaN  37.784025
# 26                              NaN                         NaN  37.782927
# 27                950 McAllister St                         NaN  37.779040
#
#            lng                                     labeledLatLngs  distance  \
# 0  -122.421762  [{'label': 'display', 'lat': 37.77586749910566...       440
# 1  -122.421992  [{'label': 'display', 'lat': 37.77601662781605...       436
# 2  -122.426202  [{'label': 'display', 'lat': 37.78060709377114...       628
# 3  -122.414402  [{'label': 'display', 'lat': 37.773783, 'lng':...       747
# 4  -122.421429  [{'label': 'display', 'lat': 37.78773094839714...       958
# 5  -122.413158  [{'label': 'display', 'lat': 37.78168454736256...       599
# 6  -122.425089  [{'label': 'display', 'lat': 37.78472011778899...       792
# 7  -122.422971  [{'label': 'display', 'lat': 37.78568764726271...       783
# 8  -122.426658  [{'label': 'display', 'lat': 37.77657839770052...       717
# 9  -122.412220  [{'label': 'display', 'lat': 37.78349501668827...       776
# 10 -122.423652  [{'label': 'display', 'lat': 37.78430416132659...       678
# 11 -122.415032  [{'label': 'display', 'lat': 37.77303844214798...       789
# 12 -122.428324  [{'label': 'display', 'lat': 37.77915867148549...       797
# 13 -122.422374  [{'label': 'display', 'lat': 37.78727015485533...       929
# 14 -122.411332  [{'label': 'display', 'lat': 37.78514255790186...       954
# 15 -122.423934  [{'label': 'display', 'lat': 37.77234190177588...       876
# 16 -122.428357  [{'label': 'display', 'lat': 37.77915054048822...       800
# 17 -122.410774  [{'label': 'display', 'lat': 37.783026, 'lng':...       854
# 18 -122.423201  [{'label': 'display', 'lat': 37.78491018486402...       715
# 19 -122.425251  [{'label': 'display', 'lat': 37.784218, 'lng':...       760
# 20 -122.421702  [{'label': 'display', 'lat': 37.78796485412996...       988
# 21 -122.423143  [{'label': 'display', 'lat': 37.784343, 'lng':...       657
# 22 -122.413077  [{'label': 'display', 'lat': 37.782953, 'lng':...       679
# 23 -122.413078  [{'label': 'display', 'lat': 37.782969, 'lng':...       680
# 24 -122.422202  [{'label': 'display', 'lat': 37.78529995482023...       717
# 25 -122.412804  [{'label': 'display', 'lat': 37.78402507, 'lng...       774
# 26 -122.413165  [{'label': 'display', 'lat': 37.782927, 'lng':...       671
# 27 -122.428512  [{'label': 'display', 'lat': 37.77904, 'lng': ...       814
#
#    postalCode  cc           city       state        country  \
# 0       94102  US  San Francisco          CA  United States
# 1       94102  US  San Francisco          CA  United States
# 2       94115  US  San Francisco          CA  United States
# 3         NaN  US  San Francisco          CA  United States
# 4       94109  US  San Francisco          CA  United States
# 5       94102  US  San Francisco          CA  United States
# 6       94109  US  San Francisco          CA  United States
# 7         NaN  US  San Francisco          CA  United States
# 8       94102  US  San Francisco          CA  United States
# 9       94102  US  San Francisco          CA  United States
# 10      94109  US  San Francisco          CA  United States
# 11      94103  US  San Francisco          CA  United States
# 12      94115  US  San Francisco          CA  United States
# 13      94109  US  San Francisco          CA  United States
# 14      94102  US  San Francisco          CA  United States
# 15      94102  US  San Francisco          CA  United States
# 16      94109  US  San Francisco          CA  United States
# 17      94102  US  San Francisco          CA  United States
# 18      94109  US  San Francisco          CA  United States
# 19      94109  US    San Quentin          CA  United States
# 20      94109  US  San Francisco          CA  United States
# 21      94109  US  San Francisco          CA  United States
# 22      94102  US  San Francisco          CA  United States
# 23      94102  US  San Francisco          CA  United States
# 24        NaN  US  San Francisco          CA  United States
# 25      94102  US  San Francisco          CA  United States
# 26        NaN  US  San Francisco          CA  United States
# 27        NaN  US            NaN  California  United States
#
#                                      formattedAddress    neighborhood  \
# 0   [261 Fell St (Franklin/Gough), San Francisco, ...             NaN
# 1   [240 Fell St (Franklin), San Francisco, CA 941...             NaN
# 2   [916 Laguna St (415-921-4935), San Francisco, ...             NaN
# 3   [1401 Howard St, San Francisco, CA, United Sta...             NaN
# 4   [1300 Van Ness Ave (Post and Geary), San Franc...  Lower Nob Hill
# 5   [133 Golden Gate Ave (Jones St), San Francisco...             NaN
# 6   [1111 Gough St (btwn Geary Blvd & Ellis St), S...             NaN
# 7                  [San Francisco, CA, United States]             NaN
# 8   [608 Hayes St, San Francisco, CA (Laguna), San...             NaN
# 9   [230 Jones St (Turk), San Francisco, CA 94102,...             NaN
# 10  [1111 Ofarrell St (btw Franklin & Gough), San ...             NaN
# 11  [1419 Howard St (between 10th & 11th), San Fra...             NaN
# 12  [950 McAllister St, San Francisco, CA 94115, U...             NaN
# 13  [1337 Sutter St (Van Ness Ave), San Francisco,...             NaN
# 14  [330 Ellis St (Ofarrell), San Francisco, CA 94...             NaN
# 15  [22 Waller St (at Octavia St.), San Francisco,...             NaN
# 16  [1541 Polk St (Sacramento), San Francisco, CA ...             NaN
# 17  [136 Taylor St (Turk St.), San Francisco, CA 9...             NaN
# 18  [1187 Franklin St (Geary), San Francisco, CA 9...             NaN
# 19  [1111 Gough St. @ Geary Blvd., San Quentin, CA...             NaN
# 20  [1290 Sutter St, San Francisco, CA 94109, Unit...             NaN
# 21  [1031 Franklin St (at O'Farrell St.), San Fran...             NaN
# 22           [San Francisco, CA 94102, United States]             NaN
# 23  [240 Turk St (Jones), San Francisco, CA 94102,...             NaN
# 24                 [San Francisco, CA, United States]             NaN
# 25  [230 Jones St, San Francisco, CA 94102, United...             NaN
# 26                 [San Francisco, CA, United States]             NaN
# 27     [950 McAllister St, California, United States]             NaN
#
#                           id
# 0   4b1324a0f964a520ab9423e3
# 1   4f25a3eae4b0c41c53d97e0f
# 2   4db46b4f81543d71da452b08
# 3   4db1e79e0cb6442b2ed407db
# 4   590618d43d47912d4bcbe52e
# 5   4bd9d33d2e6f0f47b0270c08
# 6   4a5901fff964a52072b81fe3
# 7   4e63a775e4cdf1e2bfd08494
# 8   4f25b3abe4b0b2f990bffcf6
# 9   4f3ab16ce4b059425ae6c621
# 10  4aae74b5f964a520266220e3
# 11  4e1fcb971fc7c0ef9856bfdb
# 12  50ce82c8e4b0b0b98afb8f98
# 13  4c4c7c0646240f47af17ddf4
# 14  4a882c71f964a520530520e3
# 15  4be2e78121d5a59352951711
# 16  4e5a64ef1495a891128b32ff
# 17  4bec64c4fd60a59373ef3af1
# 18  49ee3587f964a52039681fe3
# 19  51edc92b498e75cde831fe24
# 20  4c683d7c832bc9285f9eb3a8
# 21  4c4cec4674e81b8deaa9fa06
# 22  4ee01fea0e61e7dd0d1fa4c0
# 23  4e2baf15aeb745b1fac6c5f7
# 24  4e87443b5c5c38d515050d6f
# 25  4d8a85af76e1236a4c8f1c43
# 26  4e10a0aac65b4a49f305bbac
# 27  4d1541f9816af04d0f5042c2

# %% [markdown]
# #### Visualize the Churches that are 800m of City Hall

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around the Conrad Hotel

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=10,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
coordinate_df = dataframe_filtered.filter(['name','lat','lng'])
coordinate_df.head()
# Out:
#                                       name        lat         lng
# 0  Church of the Advent of Christ the King  37.775867 -122.421762
# 1       Church Of The Nativity Of Our Lord  37.776017 -122.421992
# 2                     Bethel A.M.E. Church  37.780607 -122.426202
# 3       St. Joseph's Roman Catholic Church  37.773783 -122.414402
# 4                              Hillsong SF  37.787731 -122.421429

# %% [markdown]
# #### Calculate the Proximity between every church 800m of City Hall

# %%
from geopy.distance import geodesic

# List of churches that have the proximity of 150m to 100m
lst150m = []

# List of churches that have the proximity of 100m to 50m
lst100m = []

# List of churches that have the proximity of 50m to 0m
lst50m = []

# List of churches that have the proximity of more than 150m
lst0 = []

# Define Columns
cols = ['name1','name2','lat1','lng1','lat2','lng2', "distance"]


for i , r in coordinate_df.iterrows():
    coord2 = (r['lat'],r['lng'])
    
    for ind, row in coordinate_df.iterrows():
        coord3 = (row['lat'],row['lng'])
        dis = geodesic(coord2, coord3).m
        
        if (dis < 150 and dis > 100):
            proximate = lst150m.append([row['name'],
                                        r['name'], 
                                        row['lat'], 
                                        row['lng'], 
                                        r['lat'], 
                                        r['lng'], 
                                        dis]
                                      )
            
        elif (dis < 100 and dis > 50):
            proximate = lst100m.append([row['name'], 
                                        r['name'], 
                                        row['lat'], 
                                        row['lng'], 
                                        r['lat'], 
                                        r['lng'], 
                                        dis]
                                      )
            
        elif (dis < 50 and dis != 0):
            proximate = lst50m.append([row['name'], 
                                        r['name'], 
                                        row['lat'], 
                                        row['lng'], 
                                        r['lat'], 
                                        r['lng'], 
                                        dis])
            
        elif (dis ==0):
            pass
        
        else:
            proximate = lst0.append([row['name'], 
                                     r['name'], 
                                     row['lat'], 
                                     row['lng'], 
                                     r['lat'], 
                                     r['lng'], 
                                     dis]
                                   )
            
proximate150_df = pd.DataFrame(lst150m, columns=cols)

proximate100_df = pd.DataFrame(lst100m, columns=cols)

proximate50_df = pd.DataFrame(lst50m, columns=cols)

nonproximate_df = pd.DataFrame(lst0, columns=cols)

# %%
print("Churches of Proximity of 0m to 50m")
proximate50_df.sort_values(by=['distance']).head()
# Out:
# Churches of Proximity of 0m to 50m
#                                        name1  \
# 12       TSA - Kroc Center Corps Youth Night
# 10  TSA - Kroc Center Sunday Worship Service
# 4                  St Paulus Lutheran Church
# 6                Saint Paulus Luthern Church
# 14       TSA - Kroc Center Corps Youth Night
#
#                                        name2       lat1        lng1  \
# 12  TSA - Kroc Center Sunday Worship Service  37.782953 -122.413077
# 10       TSA - Kroc Center Corps Youth Night  37.782969 -122.413078
# 4                Saint Paulus Luthern Church  37.779151 -122.428357
# 6                  St Paulus Lutheran Church  37.779159 -122.428324
# 14     TSA - Kroc Center Corps Sunday School  37.782953 -122.413077
#
#          lat2        lng2  distance
# 12  37.782969 -122.413078  1.778061
# 10  37.782953 -122.413077  1.778061
# 4   37.779159 -122.428324  3.069786
# 6   37.779151 -122.428357  3.069786
# 14  37.782927 -122.413165  8.271704

# %%
print(len(pd.unique(proximate50_df[['name1','name2']].values.ravel())))
prox50_uniq = pd.unique(proximate50_df[['name1','name2']].values.ravel())
# Out:
# 12

# %%
print("Churches of Proximity of 100m to 150m")
proximate150_df.sort_values(by=['distance']).head()
# Out:
# Churches of Proximity of 100m to 150m
#                                        name1  \
# 5      TSA - Kroc Center Corps Sunday School
# 20                            SF City Impact
# 17  TSA - Kroc Center Sunday Worship Service
# 14              San Francisco Worship Center
# 16       TSA - Kroc Center Corps Youth Night
#
#                                        name2       lat1        lng1  \
# 5                             SF City Impact  37.782927 -122.413165
# 20     TSA - Kroc Center Corps Sunday School  37.783495 -122.412220
# 17              San Francisco Worship Center  37.782969 -122.413078
# 14  TSA - Kroc Center Sunday Worship Service  37.784025 -122.412804
# 16              San Francisco Worship Center  37.782953 -122.413077
#
#          lat2        lng2    distance
# 5   37.783495 -122.412220  104.394097
# 20  37.782927 -122.413165  104.394097
# 17  37.784025 -122.412804  119.673579
# 14  37.782969 -122.413078  119.673579
# 16  37.784025 -122.412804  121.396036

# %%
print(len(pd.unique(proximate150_df[['name1','name2']].values.ravel())))
prox150_uniq = pd.unique(proximate150_df[['name1','name2']].values.ravel())
# Out:
# 12

# %%
print("Churches of Proximity of 50m to 100m")
proximate100_df.sort_values(by=['distance']).head()
# Out:
# Churches of Proximity of 50m to 100m
#                                         name1  \
# 16  Cathedral of Saint Mary of the Assumption
# 2            Church Of The Assumption Of Mary
# 14       Freedom in Christ Evangelical Church
# 18              Unitarian Universalist Church
# 13                  St Mark's Lutheran Church
#
#                                         name2       lat1        lng1  \
# 16           Church Of The Assumption Of Mary  37.784720 -122.425089
# 2   Cathedral of Saint Mary of the Assumption  37.784218 -122.425251
# 14              Unitarian Universalist Church  37.784343 -122.423143
# 18       Freedom in Christ Evangelical Church  37.784910 -122.423201
# 13              Unitarian Universalist Church  37.784304 -122.423652
#
#          lat2        lng2   distance
# 16  37.784218 -122.425251  57.533721
# 2   37.784720 -122.425089  57.533721
# 14  37.784910 -122.423201  63.162906
# 18  37.784343 -122.423143  63.162906
# 13  37.784910 -122.423201  78.092071

# %%
print(len(pd.unique(proximate100_df[['name1','name2']].values.ravel())))
prox100_uniq = pd.unique(proximate100_df[['name1','name2']].values.ravel())
# Out:
# 16

# %%
print("Churches of Proximity of more than 150m by the farthest")
nonproximate_df.sort_values(by=['distance'], ascending=False).head()
# Out:
# Churches of Proximity of more than 150m by the farthest
#                                      name1  \
# 393                  Glide Memorial Church
# 366  First Baptist Church of San Francisco
# 515                        Templo Calvario
# 294                             Journey SF
# 518  First Baptist Church of San Francisco
#
#                                      name2       lat1        lng1       lat2  \
# 393  First Baptist Church of San Francisco  37.785143 -122.411332  37.772342
# 366                  Glide Memorial Church  37.772342 -122.423934  37.785143
# 515                             Journey SF  37.773038 -122.415032  37.787965
# 294                        Templo Calvario  37.787965 -122.421702  37.773038
# 518                             Journey SF  37.772342 -122.423934  37.787965
#
#            lng2     distance
# 393 -122.423934  1803.100724
# 366 -122.411332  1803.100724
# 515 -122.421702  1757.816367
# 294 -122.415032  1757.816367
# 518 -122.421702  1745.142400

# %% [markdown]
# ### Assigned Church Occupancy to Proximity

# %% [markdown]
# Assuming that average amount of church can occupy 20 homeless', the church that has the most least amount of proximate churches would be assigned 20 occupancy, churches that has nearby churches within 100m proximity would be assigned 25, and churches that has churches in proximity within 50m would be assigned 30.

# %%
proxlist = dataframe_filtered.filter(['name','lat','lng'])
proxlist['occupancy'] = 20
for i in prox100_uniq:
    proxlist.loc[proxlist['name']== i,['occupancy']] = 25
for i in prox50_uniq:
    proxlist.loc[proxlist['name']== i,['occupancy']] = 30
proxlist
# Out:
#                                          name        lat         lng  \
# 0     Church of the Advent of Christ the King  37.775867 -122.421762
# 1          Church Of The Nativity Of Our Lord  37.776017 -122.421992
# 2                        Bethel A.M.E. Church  37.780607 -122.426202
# 3          St. Joseph's Roman Catholic Church  37.773783 -122.414402
# 4                                 Hillsong SF  37.787731 -122.421429
# 5           St Boniface Roman Catholic Church  37.781685 -122.413158
# 6   Cathedral of Saint Mary of the Assumption  37.784720 -122.425089
# 7              Hamilton Square Baptist Church  37.785688 -122.422971
# 8                 Neighborhood Baptist Church  37.776578 -122.426658
# 9                              SF City Impact  37.783495 -122.412220
# 10                  St Mark's Lutheran Church  37.784304 -122.423652
# 11                            Templo Calvario  37.773038 -122.415032
# 12                Saint Paulus Luthern Church  37.779159 -122.428324
# 13            San Francisco Lighthouse Church  37.787270 -122.422374
# 14                      Glide Memorial Church  37.785143 -122.411332
# 15      First Baptist Church of San Francisco  37.772342 -122.423934
# 16                  St Paulus Lutheran Church  37.779151 -122.428357
# 17     San Francisco City Impact Headquarters  37.783026 -122.410774
# 18              Unitarian Universalist Church  37.784910 -122.423201
# 19           Church Of The Assumption Of Mary  37.784218 -122.425251
# 20                                 Journey SF  37.787965 -122.421702
# 21       Freedom in Christ Evangelical Church  37.784343 -122.423143
# 22        TSA - Kroc Center Corps Youth Night  37.782953 -122.413077
# 23   TSA - Kroc Center Sunday Worship Service  37.782969 -122.413078
# 24                       SFGMC Rehearsal/FUUC  37.785300 -122.422202
# 25               San Francisco Worship Center  37.784025 -122.412804
# 26      TSA - Kroc Center Corps Sunday School  37.782927 -122.413165
# 27               Saint Paul's Lutheran Church  37.779040 -122.428512
#
#     occupancy
# 0          30
# 1          30
# 2          20
# 3          25
# 4          30
# 5          20
# 6          25
# 7          25
# 8          20
# 9          25
# 10         30
# 11         25
# 12         30
# 13         25
# 14         20
# 15         20
# 16         30
# 17         20
# 18         25
# 19         25
# 20         30
# 21         30
# 22         30
# 23         30
# 24         25
# 25         25
# 26         30
# 27         30

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15)
folium.features.CircleMarker(
        [37.7792929, -122.41926032381],
        radius=12,
        color='yellow',
        popup='City Hall',
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map) 

catis20 = proxlist['occupancy']==20
proxlist20 = proxlist[catis20]
catis25 = proxlist['occupancy']==25
proxlist25 = proxlist[catis25]
catis30= proxlist['occupancy']==30
proxlist30= proxlist[catis30]
for lat, lng in zip(proxlist20.lat, proxlist20.lng):
    folium.features.CircleMarker(
        [lat, lng],
        radius=8,
        color='blue',
        popup='church of 20 occupancy',
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
for lat, lng in zip(proxlist25.lat, proxlist25.lng):
    folium.features.CircleMarker(
        [lat, lng],
        radius=8,
        color='green',
        popup='church of 25 occupancy',
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(venues_map)
for lat, lng in zip(proxlist30.lat, proxlist30.lng):
    folium.features.CircleMarker(
        [lat, lng],
        radius=8,
        color='red',
        popup='church of 30 occupancy',
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map) 
# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Use K-Line Clustering for Grouping Churches for Homeless Allocation

# %%
k = 4

lat = dataframe_filtered['lat'].tolist()
lng = dataframe_filtered['lng'].tolist()
#proximate50_df
colors_map = np.array(['b', 'r'])
def assign_members(lat, lng, centers):
    compare_to_first_center = np.sqrt(np.square(np.array(lat) - centers[0][0]) + np.square(np.array(lng) - centers[0][1]))
    compare_to_second_center = np.sqrt(np.square(np.array(lat) - centers[1][0]) + np.square(np.array(lng) - centers[1][1]))
    class_of_points = compare_to_first_center > compare_to_second_center
    colors = colors_map[class_of_points + 1 - 1]
    return colors, class_of_points

# %%
# update means
def update_centers(lat, lng, class_of_points):
    center1 = [np.mean(np.array(lat)[~class_of_points]), np.mean(np.array(lng)[~class_of_points])]
    center2 = [np.mean(np.array(lat)[class_of_points]), np.mean(np.array(lng)[class_of_points])]
    return [center1, center2]

print('assign_members function defined!')
# Out:
# assign_members function defined!

# %%
from matplotlib.ticker import FormatStrFormatter
def plot_points(centroids, lat, lng, colors='g', figure_title=None):
    # plot the figure
    fig = plt.figure(figsize=(15, 10))  # create a figure object
    ax = fig.add_subplot(1, 1, 1)
    centroid_colors = ['bx', 'rx']
    if centroids:
        for (i, centroid) in enumerate(centroids):
            ax.plot(centroid[0], centroid[1], centroid_colors[i], markeredgewidth=5, markersize=20)
    #plt.plot([lat],[lng])
    plt.scatter(lat, lng, s=500, c=colors)
    # define the ticks
    xticks = np.linspace(37.77, 37.79, 15, endpoint=True)
    yticks = np.linspace(-122.44, -122.4, 20, endpoint=True)
    # fix the horfrom matplotlib.ticker import FormatStrFormatterizontal axis
    ax.set_xticks(xticks)
    ax.set_yticks(yticks)
    # add tick labels
    xlabels = xticks
    ax.set_xticklabels(xlabels)
    ylabels = yticks
    ax.set_yticklabels(ylabels)
    # style the ticks
    ax.xaxis.set_ticks_position('bottom')
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax.yaxis.set_ticks_position('left')
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax.tick_params('both', length=2, width=1, which='major', labelsize=15)
    # add labels to axes
    ax.set_xlabel('longitude', fontsize=15)
    ax.set_ylabel('latitude', fontsize=15)
    
    # add title to figure
    ax.set_title(figure_title, fontsize=24)
    plt.show()
print('plot_points function defined!')
# Out:
# plot_points function defined!

# %%
centers = [[37.772151,-122.429357],[37.785159,-122.408324]]
plot_points(centers,lat, lng, figure_title='k-means Initialization')

# %%
number_of_iterations = 4
for i in range(number_of_iterations):
    input('Iteration {} - Press Enter to update the members of each cluster'.format(i + 1))
    colors, class_of_points = assign_members(lat, lng, centers)
    title = 'Iteration {} - Cluster Assignment'.format(i + 1)
    plot_points(centers, lat, lng, colors, figure_title=title)
    input('Iteration {} - Press Enter to update the centers'.format(i + 1))
    centers = update_centers(lat, lng, class_of_points)
    title = 'Iteration {} - Centroid Update'.format(i + 1)
    plot_points(centers, lat, lng, colors, figure_title=title)
# Out:
# Iteration 1 - Press Enter to update the members of each cluster 2
# Iteration 1 - Press Enter to update the centers 2
# Iteration 2 - Press Enter to update the members of each cluster 2
# Iteration 2 - Press Enter to update the centers 2
# Iteration 3 - Press Enter to update the members of each cluster 2
# Iteration 3 - Press Enter to update the centers 2
# Iteration 4 - Press Enter to update the members of each cluster 2
# Iteration 4 - Press Enter to update the centers 2

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %%
occupany_church = proxlist['occupancy'].sum()
yr2020 = 9784 - occupany_church
difference = (yr2020/9784)
print(occupany_church)
yr2021 = difference*yr2020
year = [2007,2009,2011,2013,2015,2017,2019,2020,2021]
federal_poverty = [5703,5823,5669,7350,7539,7499,9784,yr2020,yr2021]
#state_poverty = [5703,5823,5669,7008,6775,6858,8011]
df = pd.DataFrame({'Federal Poverty':federal_poverty}, index = year)
ax = df.plot.bar(rot=0, color = [['b','b','b','b','b','b', 'b','g','g']])
# Out:
# 730

# %% [markdown]
# #### Through smart allocation of homeless between churches we would be able to achieve up to 26% efficiency in housing homeless' in a 800m radius of the San Francisco City Hall.

# %% [markdown]
# Through the smart allocation of homeless between churches, we would be able to achieve up to 23% efficiency in housing homeless' in an 800m radius of the San Francisco City Hall. This new plan would achieve up to 730 homeless housing in the city instead of 560 homeless’ and the effects would clearly be effective in fighting homelessness in San Francisco. If we would be able to roll out this throughout the San Francisco City, we can expect a minimum of 3200 to up to 4300 homeless housing in a single day. This would allow bringing the rate of homeless’ on the street to half and at a level that was ten years ago. The homeless shelter and housing would start having a vacancy and more homeless would have a chance to find a stable income. This new plan would accelerate in a decrease of homelessness in San Francisco exponentially.

# %% [markdown]
# ## Sources <a name="Source"></a>

# %% [markdown]
# Jungle, R. (n.d.). FIND APARTMENTS IN YOUR AREA. Retrieved from https://www.rentjungle.com/average-rent-in-san-francisco-rent-trends/
# Eby, K., Kgo, & Kgo. (2019, July 23). History of how many people are homeless in the Bay Area. Retrieved from https://abc7news.com/society/homeless-population-history-in-bay-area/5260657/
